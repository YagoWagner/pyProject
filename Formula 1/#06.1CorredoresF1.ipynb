# %% [markdown]
# # Fórmula 1 (1950-2020)
# Fórmula 1 com a classificação de pilotos

# %% [markdown]
# ## Sobre o conjunto de dados
# ### Contexto
# A Fórmula 1 (também conhecida como Fórmula 1 ou F1981) é a mais alta classe de automobilismo internacional de monopostos sancionada pela Fédération Internationale de l'Automobile (FIA) e de propriedade da Liberty Media, uma empresa americana de mídia de massa, através de sua subsidiária integral, o Formula One Group. O Campeonato Mundial de Pilotos, que se tornou o Campeonato Mundial de Fórmula Um da FIA em 1950, tem sido uma das principais formas de corrida em todo o mundo desde sua temporada inaugural em <>. A palavra "fórmula" no nome refere-se ao conjunto de regras às quais os carros de todos os participantes devem estar em conformidade. Uma temporada de Fórmula Um consiste em uma série de corridas, conhecidas como Grandes Prêmios (francês para "grandes prêmios" ou "grandes prêmios"), que ocorrem em todo o mundo em circuitos construídos especificamente e em vias públicas.
#
# ### Conteúdo
# Este conjunto de dados contém os dados de todos os grandes prêmios de Fórmula 1950 realizados desde <>. Também inclui os resultados das corridas, bem como a classificação dos pilotos de cada temporada e os construtores em pé.
#
# ### Inspiração
# A coleta e análise de dados é uma das partes mais vitais das corridas de Fórmula 1. Com base nos dados coletados por cada equipe, eles desenvolvem seu próprio carro, para inovar a tecnologia que usam. Sem a análise de dados em tempo real, a F1 que conhecemos hoje poderia ser muito diferente. Centenas de pontos de dados por segundo são gerados em todas as áreas-chave dos carros. Enquanto isso, engenheiros e analistas de dados, tanto no circuito quanto nas fábricas (que estão a milhares de quilômetros de distância), competem para extrair o máximo de informações possível e armar essas informações para lutar pela vitória.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import bar_chart_race as bcr
import warnings
warnings.filterwarnings("ignore")

# %%
dt_drivers = pd.read_csv(r'..\DtScience\DriversStandings.csv')
dt_drivers.tail(21)
# Out:
#       Unnamed: 0 Pos                  Driver Nationality  \
# 1552        1552   1      Lewis Hamilton HAM         GBR
# 1553        1553   2      Max Verstappen VER         NED
# 1554        1554   3     Valtteri Bottas BOT         FIN
# 1555        1555   4     Alexander Albon ALB         THA
# 1556        1556   5     Charles Leclerc LEC         MON
# 1557        1557   6        Lando Norris NOR         GBR
# 1558        1558   7        Lance Stroll STR         CAN
# 1559        1559   8    Daniel Ricciardo RIC         AUS
# 1560        1560   9        Sergio Perez PER         MEX
# 1561        1561  10        Esteban Ocon OCO         FRA
# 1562        1562  11        Carlos Sainz SAI         ESP
# 1563        1563  12        Pierre Gasly GAS         FRA
# 1564        1564  13    Sebastian Vettel VET         GER
# 1565        1565  14     Nico Hulkenberg HUL         GER
# 1566        1566  15  Antonio Giovinazzi GIO         ITA
# 1567        1567  16        Daniil Kvyat KVY         RUS
# 1568        1568  17     Kevin Magnussen MAG         DEN
# 1569        1569  18      Kimi Räikkönen RAI         FIN
# 1570        1570  19     Nicholas Latifi LAT         CAN
# 1571        1571  20      George Russell RUS         GBR
# 1572        1572  21     Romain Grosjean GRO         FRA
#
#                             Car    PTS  Year
# 1552                   Mercedes  157.0  2020
# 1553      Red Bull Racing Honda  110.0  2020
# 1554                   Mercedes  107.0  2020
# 1555      Red Bull Racing Honda   48.0  2020
# 1556                    Ferrari   45.0  2020
# 1557            McLaren Renault   45.0  2020
# 1558  Racing Point BWT Mercedes   42.0  2020
# 1559                    Renault   33.0  2020
# 1560  Racing Point BWT Mercedes   33.0  2020
# 1561                    Renault   26.0  2020
# 1562            McLaren Renault   23.0  2020
# 1563           AlphaTauri Honda   18.0  2020
# 1564                    Ferrari   16.0  2020
# 1565  Racing Point BWT Mercedes    6.0  2020
# 1566  Alfa Romeo Racing Ferrari    2.0  2020
# 1567           AlphaTauri Honda    2.0  2020
# 1568               Haas Ferrari    1.0  2020
# 1569  Alfa Romeo Racing Ferrari    0.0  2020
# 1570          Williams Mercedes    0.0  2020
# 1571          Williams Mercedes    0.0  2020
# 1572               Haas Ferrari    0.0  2020

# %%
dt_drivers=dt_drivers.drop('Unnamed: 0',axis=1)

# %%
dt_drivers=dt_drivers.query("Year != 2020")
dt_drivers
# Out:
#      Pos                  Driver Nationality                        Car   PTS  \
# 0      1         Nino Farina FAR         ITA                 Alfa Romeo  30.0
# 1      2  Juan Manuel Fangio FAN         ARG                 Alfa Romeo  27.0
# 2      3       Luigi Fagioli FAG         ITA                 Alfa Romeo  24.0
# 3      4        Louis Rosier ROS         FRA                Talbot-Lago  13.0
# 4      5      Alberto Ascari ASC         ITA                    Ferrari  11.0
# ...   ..                     ...         ...                        ...   ...
# 1547  16     Kevin Magnussen MAG         DEN               Haas Ferrari  20.0
# 1548  17  Antonio Giovinazzi GIO         ITA  Alfa Romeo Racing Ferrari  14.0
# 1549  18     Romain Grosjean GRO         FRA               Haas Ferrari   8.0
# 1550  19       Robert Kubica KUB         POL          Williams Mercedes   1.0
# 1551  20      George Russell RUS         GBR          Williams Mercedes   0.0
#
#       Year
# 0     1950
# 1     1950
# 2     1950
# 3     1950
# 4     1950
# ...    ...
# 1547  2019
# 1548  2019
# 1549  2019
# 1550  2019
# 1551  2019
#
# [1552 rows x 6 columns]

# %%
tabela=dt_drivers.set_index(['Year','Driver']).unstack()['PTS']
tabela
# Out:
# Driver  Adrian Sutil SUT  Aguri Suzuki SUZ  Alain Prost PRO  Alan Brown BRO  \
# Year
# 1950                 NaN               NaN              NaN             NaN
# 1951                 NaN               NaN              NaN             NaN
# 1952                 NaN               NaN              NaN             2.0
# 1953                 NaN               NaN              NaN             NaN
# 1954                 NaN               NaN              NaN             NaN
# ...                  ...               ...              ...             ...
# 2015                 NaN               NaN              NaN             NaN
# 2016                 NaN               NaN              NaN             NaN
# 2017                 NaN               NaN              NaN             NaN
# 2018                 NaN               NaN              NaN             NaN
# 2019                 NaN               NaN              NaN             NaN
#
# Driver  Alan Jones JON  Alberto Ascari ASC  Alessandro Nannini NAN  \
# Year
# 1950               NaN                11.0                     NaN
# 1951               NaN                25.0                     NaN
# 1952               NaN                36.0                     NaN
# 1953               NaN                34.5                     NaN
# 1954               NaN                 1.1                     NaN
# ...                ...                 ...                     ...
# 2015               NaN                 NaN                     NaN
# 2016               NaN                 NaN                     NaN
# 2017               NaN                 NaN                     NaN
# 2018               NaN                 NaN                     NaN
# 2019               NaN                 NaN                     NaN
#
# Driver  Alessandro Zanardi ZAN  Alex Caffi CAF  Alex Yoong YOO  ...  \
# Year                                                            ...
# 1950                       NaN             NaN             NaN  ...
# 1951                       NaN             NaN             NaN  ...
# 1952                       NaN             NaN             NaN  ...
# 1953                       NaN             NaN             NaN  ...
# 1954                       NaN             NaN             NaN  ...
# ...                        ...             ...             ...  ...
# 2015                       NaN             NaN             NaN  ...
# 2016                       NaN             NaN             NaN  ...
# 2017                       NaN             NaN             NaN  ...
# 2018                       NaN             NaN             NaN  ...
# 2019                       NaN             NaN             NaN  ...
#
# Driver  Vittorio Brambilla BRA  Walt Faulkner FAU  Walt Hansgen HAN  \
# Year
# 1950                       NaN                NaN               NaN
# 1951                       NaN                NaN               NaN
# 1952                       NaN                NaN               NaN
# 1953                       NaN                NaN               NaN
# 1954                       NaN                NaN               NaN
# ...                        ...                ...               ...
# 2015                       NaN                NaN               NaN
# 2016                       NaN                NaN               NaN
# 2017                       NaN                NaN               NaN
# 2018                       NaN                NaN               NaN
# 2019                       NaN                NaN               NaN
#
# Driver  Will Stevens STE  Willy Mairesse MAI  Wilson Fittipaldi FIT  \
# Year
# 1950                 NaN                 NaN                    NaN
# 1951                 NaN                 NaN                    NaN
# 1952                 NaN                 NaN                    NaN
# 1953                 NaN                 NaN                    NaN
# 1954                 NaN                 NaN                    NaN
# ...                  ...                 ...                    ...
# 2015                 0.0                 NaN                    NaN
# 2016                 NaN                 NaN                    NaN
# 2017                 NaN                 NaN                    NaN
# 2018                 NaN                 NaN                    NaN
# 2019                 NaN                 NaN                    NaN
#
# Driver  Wolfgang von Trips VON  Yuji Ide IDE  Yves Giraud Cabantous CAB  \
# Year
# 1950                       NaN           NaN                        3.0
# 1951                       NaN           NaN                        2.0
# 1952                       NaN           NaN                        NaN
# 1953                       NaN           NaN                        NaN
# 1954                       NaN           NaN                        NaN
# ...                        ...           ...                        ...
# 2015                       NaN           NaN                        NaN
# 2016                       NaN           NaN                        NaN
# 2017                       NaN           NaN                        NaN
# 2018                       NaN           NaN                        NaN
# 2019                       NaN           NaN                        NaN
#
# Driver  Zsolt Baumgartner BAU
# Year
# 1950                      NaN
# 1951                      NaN
# 1952                      NaN
# 1953                      NaN
# 1954                      NaN
# ...                       ...
# 2015                      NaN
# 2016                      NaN
# 2017                      NaN
# 2018                      NaN
# 2019                      NaN
#
# [70 rows x 387 columns]

# %%
novus=tabela.fillna(0)

# %%
bcr.bar_chart_race(df=novus,
                    n_bars=12,
                    title='Classificação de Pilotos de Fórmula 1 1958-2019',
                    sort='desc',
                    steps_per_period=1,
                    filename=None
)
# Out:
# <video width="1054" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
